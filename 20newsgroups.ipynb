# %%
from sklearn.datasets import fetch_20newsgroups

# %%
news_data = fetch_20newsgroups(subset='all', remove=['header', 'footers', 'quotes'])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
news_data.data[0].split('\n')
# Out:
# ['From: Mamatha Devineni Ratnam <mr47+@andrew.cmu.edu>',
#  'Subject: Pens fans reactions',
#  'Organization: Post Office, Carnegie Mellon, Pittsburgh, PA',
#  'Lines: 12',
#  'NNTP-Posting-Host: po4.andrew.cmu.edu',
#  '',
#  '']

# %%
news_data.target
# Out:
# array([10,  3, 17, ...,  3,  1,  7])

# %%
news_data.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
[x for x in news_data.data[1].split('\n') if x.find('Subject:') == 0]
# Out:
# ["Subject: Re: 14 Apr 93   God's Promise in 1 John 1: 7"]

# %%
news_data.data[10].split('\n')[1]
# Out:
# "Subject: Re: 14 Apr 93   God's Promise in 1 John 1: 7"

# %%
subject_li = []
for i in news_data.data:
  subject = [x for x in i.split('\n') if x.find('Subject:') == 0]
    subject = [x.split(':') if ' Re:' in subject]
  subject_li.append(subject[0])

# %%
subject_li
# Out:
# ['Pens fans reactions',
#  'Which high-performance VLB video card?',
#  'ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES (Henrik)',
#  'IDE vs SCSI, DMA and detach',
#  'driver ??',
#  'subliminal message flashing on TV',
#  'Number for Applied Engineering',
#  'Atlanta Hockey Hell!!',
#  'Goalie masks',
#  'Christians above the Law? was Clarification of pe',
#  '7',
#  'Fighting the Clipper Initiative',
#  'OTO, the Ancient Order of Oriental Templars',
#  'Krillean Photography',
#  'Genocide is Caused by Atheism)',
#  '"Stretching from the Adriatic Sea to the Great Wall of China"',
#  '600RPM Floopy drives - UPDATE!',
#  'WD-40 as moisture repellant (was Lead Acid batteries & C',
#  'text of White House announcement and Q&As on clipper chip encryption',
#  'Countersteering_FAQ please post',
#  'Chevy/GMC 4x4 Fullsize Pickups, Opinions?',
#  'Any way to *STOP* and application from re-titling?',
#  'HOT NEW 3D Software',
#  'Back Breaker, Near Hit!!',
#  '1993 NHL Draft',
# ...

# %%
[i.split('\n')[1].split(':')[-1] for i in news_data.data]
# Out:
# [' Pens fans reactions',
#  ' Which high-performance VLB video card?',
#  ' ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES (Henrik)',
#  ' IDE vs SCSI, DMA and detach',
#  ' driver ??',
#  ' subliminal message flashing on TV',
#  ' Number for Applied Engineering',
#  ' Atlanta Hockey Hell!!',
#  ' Goalie masks',
#  ' Christians above the Law? was Clarification of pe',
#  ' 7',
#  ' Fighting the Clipper Initiative',
#  ' OTO, the Ancient Order of Oriental Templars',
#  ' Krillean Photography',
#  ' Genocide is Caused by Atheism)',
#  ' "Stretching from the Adriatic Sea to the Great Wall of China"',
#  ' 600RPM Floopy drives - UPDATE!',
#  ' WD-40 as moisture repellant (was Lead Acid batteries & C',
#  ' text of White House announcement and Q&As on clipper chip encryption',
#  ' Countersteering_FAQ please post',
#  ' Chevy/GMC 4x4 Fullsize Pickups, Opinions?',
#  ' Any way to *STOP* and application from re-titling?',
#  ' HOT NEW 3D Software',
#  ' Back Breaker, Near Hit!!',
# ...
